# %%
# %pip install mesa==2.3.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mesa==2.3.2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.3.2)
# Requirement already satisfied: click in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (8.1.8)
# Requirement already satisfied: cookiecutter in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (2.6.0)
# Requirement already satisfied: matplotlib in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (3.10.1)
# Requirement already satisfied: mesa-viz-tornado>=0.1.3,~=0.1.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (0.1.3)
# Requirement already satisfied: networkx in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (3.4.2)
# Requirement already satisfied: numpy in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (1.26.4)
# Requirement already satisfied: pandas in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (2.2.3)
# Requirement already satisfied: solara in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (1.45.0)
# Requirement already satisfied: tqdm in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa==2.3.2) (4.67.1)
# Requirement already satisfied: tornado in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mesa-viz-tornado>=0.1.3,~=0.1.0->mesa==2.3.2) (6.4.2)
# Requirement already satisfied: colorama in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click->mesa==2.3.2) (0.4.6)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cookiecutter->mesa==2.3.2) (0.4.4)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cookiecutter->mesa==2.3.2) (3.1.5)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cookiecutter->mesa==2.3.2) (6.0.2)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cookiecutter->mesa==2.3.2) (8.0.4)
# Requirement already satisfied: requests>=2.23.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cookiecutter->mesa==2.3.2) (2.32.3)
# Requirement already satisfied: arrow in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cookiecutter->mesa==2.3.2) (1.3.0)
# Requirement already satisfied: rich in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cookiecutter->mesa==2.3.2) (13.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mesa==2.3.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->mesa==2.3.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas->mesa==2.3.2) (2024.2)
# Requirement already satisfied: solara-server==1.45.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (1.45.0)
# Requirement already satisfied: solara-ui==1.45.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara->mesa==2.3.2) (1.45.0)
# Requirement already satisfied: filelock in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (3.18.0)
# Requirement already satisfied: ipykernel in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (6.29.5)
# Requirement already satisfied: jupyter-client in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (8.6.3)
# Requirement already satisfied: nbformat in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (5.10.4)
# Requirement already satisfied: rich-click in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (1.8.8)
# Requirement already satisfied: watchdog in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (6.0.0)
# Requirement already satisfied: watchfiles in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (1.0.5)
# Requirement already satisfied: starlette in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (0.46.2)
# Requirement already satisfied: uvicorn in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (0.34.2)
# Requirement already satisfied: websockets in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (15.0.1)
# Requirement already satisfied: humanize in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (4.12.2)
# Requirement already satisfied: ipyvue>=1.9.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (1.11.2)
# Requirement already satisfied: ipyvuetify>=1.6.10 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (1.11.1)
# Requirement already satisfied: ipywidgets>=7.7 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (8.1.6)
# Requirement already satisfied: reacton>=1.9 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (1.9.1)
# Requirement already satisfied: cachetools in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara->mesa==2.3.2) (5.5.2)
# Requirement already satisfied: markdown in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara->mesa==2.3.2) (3.8)
# Requirement already satisfied: pygments in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara->mesa==2.3.2) (2.18.0)
# Requirement already satisfied: pymdown-extensions in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara->mesa==2.3.2) (10.14.3)
# Requirement already satisfied: chardet>=3.0.2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from binaryornot>=0.4.4->cookiecutter->mesa==2.3.2) (5.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter->mesa==2.3.2) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->mesa==2.3.2) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-slugify>=4.0.0->cookiecutter->mesa==2.3.2) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.23.0->cookiecutter->mesa==2.3.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.23.0->cookiecutter->mesa==2.3.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.23.0->cookiecutter->mesa==2.3.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests>=2.23.0->cookiecutter->mesa==2.3.2) (2024.12.14)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from arrow->cookiecutter->mesa==2.3.2) (2.9.0.20241206)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich->cookiecutter->mesa==2.3.2) (3.0.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (3.0.14)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich->cookiecutter->mesa==2.3.2) (0.1.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from reacton>=1.9->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (4.12.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (1.8.11)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (1.6.0)
# Requirement already satisfied: psutil in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (26.2.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (4.23.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from starlette->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (4.9.0)
# Requirement already satisfied: h11>=0.8 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (1.3.1)
# Requirement already satisfied: decorator in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (3.0.48)
# Requirement already satisfied: stack_data in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara->mesa==2.3.2) (308)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara->mesa==2.3.2) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install solara
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: solara in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.45.0)
# Requirement already satisfied: solara-server==1.45.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara) (1.45.0)
# Requirement already satisfied: solara-ui==1.45.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara) (1.45.0)
# Requirement already satisfied: click>=7.1.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (8.1.8)
# Requirement already satisfied: filelock in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (3.18.0)
# Requirement already satisfied: ipykernel in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (6.29.5)
# Requirement already satisfied: jinja2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (3.1.5)
# Requirement already satisfied: jupyter-client in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (8.6.3)
# Requirement already satisfied: nbformat in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (5.10.4)
# Requirement already satisfied: rich-click in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (1.8.8)
# Requirement already satisfied: watchdog in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara) (6.0.0)
# Requirement already satisfied: watchfiles in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara) (1.0.5)
# Requirement already satisfied: starlette in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara) (0.46.2)
# Requirement already satisfied: uvicorn in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara) (0.34.2)
# Requirement already satisfied: websockets in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-server[dev,starlette]==1.45.0->solara) (15.0.1)
# Requirement already satisfied: humanize in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (4.12.2)
# Requirement already satisfied: ipyvue>=1.9.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (1.11.2)
# Requirement already satisfied: ipyvuetify>=1.6.10 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (1.11.1)
# Requirement already satisfied: ipywidgets>=7.7 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (8.1.6)
# Requirement already satisfied: reacton>=1.9 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (1.9.1)
# Requirement already satisfied: requests in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (2.32.3)
# Requirement already satisfied: cachetools in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara) (5.5.2)
# Requirement already satisfied: markdown in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara) (3.8)
# Requirement already satisfied: numpy in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara) (1.26.4)
# Requirement already satisfied: pillow in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara) (11.1.0)
# Requirement already satisfied: pygments in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara) (2.18.0)
# Requirement already satisfied: pymdown-extensions in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from solara-ui[all]==1.45.0->solara) (10.14.3)
# Requirement already satisfied: colorama in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from click>=7.1.0->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.14 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (3.0.14)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from reacton>=1.9->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (4.12.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (1.8.11)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (1.6.0)
# Requirement already satisfied: packaging in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (24.2)
# Requirement already satisfied: psutil in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (6.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-client->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (2.1.5)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (4.23.0)
# Requirement already satisfied: pyyaml in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pymdown-extensions->solara-ui[all]==1.45.0->solara) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (2024.12.14)
# Requirement already satisfied: rich>=10.7 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich-click->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (13.9.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from starlette->solara-server[dev,starlette]==1.45.0->solara) (4.9.0)
# Requirement already satisfied: h11>=0.8 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from uvicorn->solara-server[dev,starlette]==1.45.0->solara) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.45.0->solara) (1.3.1)
# Requirement already satisfied: decorator in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (3.0.48)
# Requirement already satisfied: stack_data in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jsonschema>=2.6->nbformat->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (308)
# Requirement already satisfied: six>=1.5 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->jupyter-client->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rich>=10.7->rich-click->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (3.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->solara-server==1.45.0->solara-server[dev,starlette]==1.45.0->solara) (0.1.2)
# Requirement already satisfied: wcwidth in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\alanr\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.7->solara-ui==1.45.0->solara-ui[all]==1.45.0->solara) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mesa.space import NetworkGrid
from mesa.datacollection import DataCollector
import networkx as nx
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector

# %%
# --- Voter Agent ---

class VoterAgent(Agent):
    def __init__(self, unique_id, model, initial_state='S', resistance=0.1, decay_prob=0.05, threshold=0.5, group=None, x=0, y=0):
        super().__init__(unique_id, model)
        self.state = initial_state
        self.resistance = resistance
        self.previous_state = initial_state
        self.decay_prob = decay_prob
        self.threshold = threshold
        self.group = group or self.random.choice(['Youth', 'Senior', 'Urban', 'Rural'])
        self.x = x  # Geographic X position
        self.y = y  # Geographic Y position

    def step(self):
        if self.state in ['A', 'B'] and self.random.random() < self.decay_prob:
            self.state = 'S'
            return

        if self.state != 'S':
            return

        neighbors = self.model.grid.get_neighbors(self.pos)
        influence_A = sum(1 for n in neighbors if n.state == 'A')
        influence_B = sum(1 for n in neighbors if n.state == 'B')
        total = len(neighbors)

        if total == 0:
            return

        if influence_A / total >= self.threshold:
            new_state = 'A'
        elif influence_B / total >= self.threshold:
            new_state = 'B'
        else:
            return

        if self.random.random() > self.resistance:
            if self.previous_state != new_state:
                self.resistance = min(1.0, self.resistance + 0.1)
            self.previous_state = self.state
            self.state = new_state

    # Method to calculate geographical influence
    def get_distance(self, other_agent):
        return ((self.x - other_agent.x)**2 + (self.y - other_agent.y)**2)**0.5

# --- Candidate Agent ---
class CandidateAgent(Agent): 
    def __init__(self, unique_id, model, party, reach_prob=0.1):
        super().__init__(unique_id, model)
        self.party = party
        self.reach_prob = reach_prob
        self.x = self.random.random()  # Candidate's position on the x-axis
        self.y = self.random.random()  # Candidate's position on the y-axis

    def get_distance(self, other_agent):
        """
        Calculate the Euclidean distance between this candidate and another agent (voter or media).
        """
        if isinstance(other_agent, VoterAgent) or isinstance(other_agent, MediaAgent):
            # Compute Euclidean distance
            distance = ((self.x - other_agent.x) ** 2 + (self.y - other_agent.y) ** 2) ** 0.5
            return distance
        else:
            return None
        
    def step(self):
        support = {'A': 0, 'B': 0, 'S': 0}
        for a in self.model.schedule.agents:
            if isinstance(a, VoterAgent):
                support[a.state] += 1

        if self.party == 'A' and support['A'] < support['B']:
            self.reach_prob = min(1.0, self.reach_prob + 0.05)
        elif self.party == 'B' and support['B'] < support['A']:
            self.reach_prob = min(1.0, self.reach_prob + 0.05)

        for a in self.model.schedule.agents:
            if isinstance(a, VoterAgent) and a.state == 'S':
                distance = self.get_distance(a)
                influence = self.reach_prob / (1 + distance)  # Influence is inversely related to distance
                if self.random.random() < influence:
                    a.state = self.party

# --- Media Agent ---
class MediaAgent(Agent):
    def __init__(self, unique_id, model, target='A', influence_strength=0.3, trigger_step=10):
        super().__init__(unique_id, model)
        self.target = target  # Targeting 'A' or 'B'
        self.influence_strength = influence_strength  # Influence strength of media
        self.trigger_step = trigger_step  # When to trigger the media influence

    def step(self):
        # Dynamic triggering based on trends
        if self.model.schedule.steps % self.trigger_step == 0:
            for a in self.model.schedule.agents:
                if isinstance(a, VoterAgent) and a.state == 'S':  # Only target undecided voters
                    # Influence probability based on media strength and current media target
                    prob = self.influence_strength
                    if self.random.random() < prob:
                        a.state = self.target  # Change the state to the target party


# --- Election Model ---
class ElectionModel(Model):
    def __init__(self, N=100, decay_prob=0.05, threshold=0.5, media_count=2, communities=3):
        # Create a probability matrix for the stochastic block model
        # p[i][j] is the probability of an edge between nodes in community i and community j
        p = [[0.2 if i != j else 0.4 for i in range(communities)] for j in range(communities)]
        
        # Create a stochastic block model graph
        self.G = nx.stochastic_block_model([N//communities]*communities, p)
        
        self.grid = NetworkGrid(self.G)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={
                'A': lambda m: sum(1 for a in m.schedule.agents if isinstance(a, VoterAgent) and a.state == 'A'),
                'B': lambda m: sum(1 for a in m.schedule.agents if isinstance(a, VoterAgent) and a.state == 'B'),
                'S': lambda m: sum(1 for a in m.schedule.agents if isinstance(a, VoterAgent) and a.state == 'S'),
            }
        )

        for node_id in self.G.nodes:
            group = 'Urban' if node_id % 2 == 0 else 'Rural'
            # Geographical position for each agent (randomly placed)
            x, y = self.random.random(), self.random.random()
            a = VoterAgent(node_id, self, decay_prob=decay_prob, threshold=threshold, group=group, x=x, y=y)
            self.grid.place_agent(a, node_id)  # Place agent at node_id in the network
            self.schedule.add(a)

        for i in range(media_count):
            target = 'A' if i % 2 == 0 else 'B'
            media_agent = MediaAgent(f'media_{i}', self, target=target, influence_strength=0.3, trigger_step=10)
            self.schedule.add(media_agent)

        self.candA = CandidateAgent('candA', self, party='A')
        self.candB = CandidateAgent('candB', self, party='B')
        self.schedule.add(self.candA)
        self.schedule.add(self.candB)

        self.final_results = None

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

    def hold_election(self):
        vote_counts = {'A': 0, 'B': 0}
        for a in self.schedule.agents:
            if isinstance(a, VoterAgent):
                if a.state in ['A', 'B']:
                    vote_counts[a.state] += 1
        self.final_results = vote_counts
        print("\nElection Results:")
        print(f"Candidate A: {vote_counts['A']} votes")
        print(f"Candidate B: {vote_counts['B']} votes")

# %%
def run_model(N=100, steps=30, decay_prob=0.05, threshold=0.5, media_count=2, communities=3):
    model = ElectionModel(N=N, decay_prob=decay_prob, threshold=threshold, media_count=media_count, communities=communities)
    for _ in range(steps):
        model.step()

    results = model.datacollector.get_model_vars_dataframe()
    results.plot(marker='o', figsize=(10, 6), grid=True, title="Election Dynamics")
    plt.xlabel("Step")
    plt.ylabel("Number of Voters")
    plt.show()

    model.hold_election()

# --- Widgets ---
widgets.interact(
    run_model,
    N=widgets.IntSlider(value=100, min=20, max=300, step=10, description='Voters'),
    steps=widgets.IntSlider(value=30, min=10, max=100, step=5, description='Steps'),
    decay_prob=widgets.FloatSlider(value=0.05, min=0.0, max=0.2, step=0.01, description='Decay Prob'),
    threshold=widgets.FloatSlider(value=0.5, min=0.0, max=1.0, step=0.05, description='Threshold'),
    media_count=widgets.IntSlider(value=2, min=1, max=5, step=1, description='Media Agents'),
    communities=widgets.IntSlider(value=3, min=2, max=5, step=1, description='Communities')
)
# Out:
# interactive(children=(IntSlider(value=100, description='Voters', max=300, min=20, step=10), IntSlider(value=30…
# <function __main__.run_model(N=100, steps=30, decay_prob=0.05, threshold=0.5, media_count=2, communities=3)>

# %%
import random

# %%
class OpinionAgent(Agent):
    """ An agent with an opinion, based on DeGroot's model. """
    def __init__(self, unique_id, model, opinion, neighbors):
        super().__init__(unique_id, model)
        self.opinion = opinion  # Opinion of the agent (between 0 and 1, for example)
        self.neighbors = neighbors  # List of neighboring agents

    def step(self):
        # Update the agent's opinion based on the weighted average of neighbors' opinions
        total_opinion = 0
        total_weight = 0
        for neighbor in self.neighbors:
            weight = self.model.get_weight(self, neighbor)
            total_opinion += weight * neighbor.opinion
            total_weight += weight
        # Normalize the opinion to be between 0 and 1 (optional)
        self.opinion = total_opinion / total_weight if total_weight != 0 else self.opinion

class OpinionDynamicsModel(Model):
    """ The model for simulating opinion dynamics using DeGroot's model. """
    def __init__(self, num_agents, width, height):
        self.num_agents = num_agents
        self.grid = MultiGrid(width, height, True)
        self.schedule = RandomActivation(self)

        # Create agents with random initial opinions between 0 and 1
        for i in range(self.num_agents):
            opinion = random.random()  # Random initial opinion
            # Assuming a random connection for simplicity here
            neighbors = []  # Initially, no neighbors
            a = OpinionAgent(i, self, opinion, neighbors)
            self.schedule.add(a)
            x = self.random.randrange(self.grid.width)
            y = self.random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

        # Data collection
        self.datacollector = DataCollector(
            agent_reporters={"Opinion": "opinion"}
        )

    def get_weight(self, agent1, agent2):
        # Simple function to define the weight of one agent's influence on another.
        # This could be based on social distance, network connection, etc.
        # For simplicity, here we use a fixed weight
        return 1 / len(agent1.neighbors) if len(agent1.neighbors) > 0 else 1

    def step(self):
        # Collect data for each step
        self.datacollector.collect(self)

        # Update opinions of all agents
        self.schedule.step()

# %%
# Run the model
model = OpinionDynamicsModel(100, 10, 10)

for i in range(100):  # Run for 100 steps
    model.step()

# Extract data for analysis
data = model.datacollector.get_agent_vars_dataframe()
print(data.tail())
# Out:
#                Opinion
# Step AgentID
# 99   81       0.951815
#      12       0.498503
#      59       0.486528
#      2        0.896221
#      89       0.987667
# C:\Users\alanr\AppData\Local\Temp\ipykernel_8684\3538373494.py:4: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
